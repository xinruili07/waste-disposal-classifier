# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from keras.models import model_from_json
from keras.models import load_model
import matplotlib.pyplot as plt
from fastai.vision import *

from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import os
import shutil
import re
import seaborn as sns



## splits indices for a folder into train, validation, and test indices with random sampling   
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    ## train indices
    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.5*n))

    ## temp
    remain = list(set(full_set)-set(train))

    ## separate remaining into validation and test
    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

## gets file names for a particular type of trash, given indices
def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

## moves group of source files to another folder
def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %%
DATADIR = "dataset-resized"
SUBSETS = ["train", "valid"]
CATEGORIES = ["cardboard", "glass", "metal", "paper", "plastic", "trash"]
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))

for subset in SUBSETS:
    for waste_type in CATEGORIES:
        folder = os.path.join('data',subset,waste_type)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
if not os.path.exists(os.path.join('data','test')):
    os.makedirs(os.path.join('data','test'))
    
for waste_type in CATEGORIES:
    source_folder = os.path.join('dataset-resized', waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = "data/train/"+waste_type
    move_files(train_source_files,train_dest)
    
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = "data/valid/"+waste_type
    move_files(valid_source_files,valid_dest)
    
    test_names = get_names(waste_type,test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    move_files(test_source_files,"data/test")

# %%
path = os.getcwd() +"/data"
path
# Out:
# '/Users/xinruili/Desktop/ImplementAi/data'

# %%
tfms = get_transforms(do_flip=True,flip_vert=True)
data = ImageDataBunch.from_folder(path,test="test",ds_tfms=tfms,bs=16, num_workers=0)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/xinruili/Desktop/ImplementAi/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/xinruili/Desktop/ImplementAi/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /Users/xinruili/Desktop/ImplementAi/data

# %%
print(data.classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit_one_cycle(20,1e-2)
learn.save('mini_train')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
interp.plot_confusion_matrix(figsize=(20,20), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('plastic', 'glass', 21),
#  ('metal', 'glass', 14),
#  ('cardboard', 'paper', 12),
#  ('glass', 'plastic', 10),
#  ('glass', 'trash', 8),
#  ('metal', 'plastic', 8),
#  ('metal', 'trash', 8),
#  ('trash', 'paper', 7),
#  ('plastic', 'paper', 6),
#  ('glass', 'metal', 5),
#  ('metal', 'paper', 5),
#  ('plastic', 'trash', 5),
#  ('trash', 'plastic', 5),
#  ('metal', 'cardboard', 4),
#  ('paper', 'cardboard', 4),
#  ('paper', 'metal', 4),
#  ('paper', 'trash', 4),
#  ('plastic', 'metal', 3),
#  ('trash', 'cardboard', 3),
#  ('cardboard', 'metal', 2),
#  ('cardboard', 'plastic', 2),
#  ('cardboard', 'trash', 2),
#  ('plastic', 'cardboard', 2)]

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %%
print(preds[0].shape)
preds[0]
# Out:
# torch.Size([635, 6])
# tensor([[7.9597e-01, 5.9985e-03, 5.0313e-03, 9.6043e-03, 4.4062e-04, 1.8296e-01],
#         [5.1542e-05, 3.1817e-04, 9.9904e-01, 6.6040e-07, 5.0307e-04, 8.8970e-05],
#         [1.7918e-06, 1.6511e-04, 7.2369e-06, 2.0090e-08, 9.9982e-01, 9.1694e-06],
#         ...,
#         [4.7864e-04, 3.3534e-04, 1.6686e-03, 3.9927e-01, 5.8404e-01, 1.4213e-02],
#         [1.0090e-03, 5.1963e-04, 3.2665e-04, 9.4830e-01, 3.3487e-03, 4.6500e-02],
#         [6.5642e-08, 4.1266e-03, 5.0115e-07, 3.7307e-12, 9.9587e-01, 6.6892e-08]])

# %%
## saves the index (0 to 5) of most likely (max) predicted class for each image
max_idxs = np.asarray(np.argmax(preds[0],axis=1))

# %%
yhat = []
for max_idx in max_idxs:
    yhat.append(data.classes[max_idx])
yhat
# Out:
# ['cardboard',
#  'metal',
#  'plastic',
#  'glass',
#  'plastic',
#  'trash',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'metal',
#  'cardboard',
#  'plastic',
#  'metal',
#  'trash',
#  'paper',
#  'trash',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'trash',
#  'plastic',
#  'plastic',
#  'glass',
#  'trash',
#  'plastic',
#  'metal',
#  'glass',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'trash',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'cardboard',
#  'paper',
#  'metal',
#  'metal',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'trash',
#  'plastic',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'paper',
#  'metal',
#  'glass',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'trash',
#  'trash',
#  'plastic',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'cardboard',
#  'metal',
#  'trash',
#  'trash',
#  'metal',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'trash',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'trash',
#  'metal',
#  'glass',
#  'trash',
#  'glass',
#  'trash',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'trash',
#  'plastic',
#  'trash',
#  'plastic',
#  'cardboard',
#  'paper',
#  'trash',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'metal',
#  'paper',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'cardboard',
#  'trash',
#  'trash',
#  'plastic',
#  'glass',
#  'trash',
#  'glass',
#  'glass',
#  'trash',
#  'plastic',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'trash',
#  'plastic',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'trash',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'metal',
#  'cardboard',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'trash',
#  'plastic',
#  'cardboard',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'trash',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'glass',
#  'trash',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'glass',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'paper',
#  'metal',
#  'trash',
#  'plastic',
#  'paper',
#  'paper',
#  'trash',
#  'plastic',
#  'trash',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'plastic',
#  'metal',
#  'trash',
#  'trash',
#  'glass',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'trash',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'trash',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'trash',
#  'glass',
#  'glass',
#  'trash',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'plastic']

# %%
learn.data.test_ds[0][0]
# Out:
# Image (3, 384, 512)

# %%
y = []

## convert POSIX paths to string first
for label_path in data.test_ds.items:
    y.append(str(label_path))
    
## then extract waste type from file path
pattern = re.compile("([a-z]+)[0-9]+")
for i in range(len(y)):
    y[i] = pattern.search(y[i]).group(1)

# %%
## predicted values
print(yhat[0:5])
## actual values
print(y[0:5])
# Out:
# ['cardboard', 'metal', 'plastic', 'glass', 'plastic']
# ['cardboard', 'metal', 'plastic', 'trash', 'plastic']

# %%
cm = confusion_matrix(y,yhat)
print(cm)
# Out:
# [[ 80   0   1  19   1   0]
#  [  0 102   6   3  15   0]
#  [  3  24  56   4   7   9]
#  [  4   3   4 135   1   2]
#  [  0  17   3   5  92   4]
#  [  1   4   0   4   3  23]]

# %%
df_cm = pd.DataFrame(cm,CATEGORIES,CATEGORIES)

plt.figure(figsize=(10,8))
sns.heatmap(df_cm,annot=True,fmt="d",cmap="YlGnBu")

# %%
correct = 0

for r in range(len(cm)):
    for c in range(len(cm)):
        if (r==c):
            correct += cm[r,c]

# %%
accuracy = correct/sum(sum(cm))
accuracy
# Out:
# 0.768503937007874

# %%
model_json = learn.to_json()
with open("model.json", "w") as json_file :
	json_file.write(model_json)

model.save_weights("model.h5")
print("Saved model to disk")

model.save('CNN.model')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-905ce03d2f57> in <module>
# ----> 1 model_json = learn.to_json()
#       2 with open("model.json", "w") as json_file :
#       3         json_file.write(model_json)
#       4
#       5 model.save_weights("model.h5")
#
# AttributeError: 'Learner' object has no attribute 'to_json'
