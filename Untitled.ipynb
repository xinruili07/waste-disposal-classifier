# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from keras.models import model_from_json
from keras.models import load_model
import matplotlib.pyplot as plt
from fastai.vision import *

from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import os
import shutil
import re
import seaborn as sns



## splits indices for a folder into train, validation, and test indices with random sampling   
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    ## train indices
    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.5*n))

    ## temp
    remain = list(set(full_set)-set(train))

    ## separate remaining into validation and test
    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

## gets file names for a particular type of trash, given indices
def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

## moves group of source files to another folder
def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %%
DATADIR = "dataset-resized"
SUBSETS = ["train", "valid"]
CATEGORIES = ["cardboard", "glass", "metal", "paper", "plastic", "trash"]
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))

for subset in SUBSETS:
    for waste_type in CATEGORIES:
        folder = os.path.join('data',subset,waste_type)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
if not os.path.exists(os.path.join('data','test')):
    os.makedirs(os.path.join('data','test'))
    
for waste_type in CATEGORIES:
    source_folder = os.path.join('dataset-resized', waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = "data/train/"+waste_type
    move_files(train_source_files,train_dest)
    
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = "data/valid/"+waste_type
    move_files(valid_source_files,valid_dest)
    
    test_names = get_names(waste_type,test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    move_files(test_source_files,"data/test")

# %%
path = os.getcwd() +"/data"
path
# Out:
# '/Users/xinruili/Desktop/ImplementAi/data'

# %%
tfms = get_transforms(do_flip=True,flip_vert=True)
data = ImageDataBunch.from_folder(path,test="test",ds_tfms=tfms,bs=16, num_workers=0)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/xinruili/Desktop/ImplementAi/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /Users/xinruili/Desktop/ImplementAi/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /Users/xinruili/Desktop/ImplementAi/data

# %%
print(data.classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit_one_cycle(1,1e-2)
learn.save('mini_train')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.737964</td>
#       <td>0.834562</td>
#       <td>0.734921</td>
#       <td>15:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
interp.plot_confusion_matrix(figsize=(20,20), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('plastic', 'glass', 20),
#  ('glass', 'plastic', 19),
#  ('plastic', 'paper', 18),
#  ('paper', 'cardboard', 14),
#  ('glass', 'metal', 13),
#  ('cardboard', 'paper', 11),
#  ('metal', 'glass', 11),
#  ('trash', 'paper', 10),
#  ('metal', 'cardboard', 6),
#  ('metal', 'plastic', 6),
#  ('trash', 'plastic', 5),
#  ('cardboard', 'metal', 4),
#  ('cardboard', 'plastic', 4),
#  ('paper', 'metal', 4),
#  ('trash', 'cardboard', 4),
#  ('glass', 'cardboard', 3),
#  ('metal', 'paper', 3),
#  ('trash', 'metal', 3),
#  ('glass', 'paper', 2),
#  ('trash', 'glass', 2)]

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %%
print(preds[0].shape)
preds[0]
# Out:
# torch.Size([635, 6])
# tensor([[1.2802e-01, 3.2004e-01, 7.5200e-02, 2.2539e-01, 1.0461e-01, 1.4674e-01],
#         [1.8416e-06, 1.3317e-04, 9.9368e-01, 1.8016e-08, 6.1737e-03, 8.4580e-06],
#         [3.1353e-05, 7.1988e-05, 2.1816e-04, 8.8600e-07, 9.9968e-01, 7.2576e-07],
#         ...,
#         [2.9334e-03, 4.3917e-05, 9.5235e-05, 9.9629e-01, 1.3682e-04, 4.9648e-04],
#         [9.9226e-05, 9.4603e-04, 1.4845e-03, 9.4799e-01, 4.0587e-02, 8.8903e-03],
#         [1.5084e-05, 5.2931e-03, 3.1962e-06, 1.3314e-07, 9.9466e-01, 3.2177e-05]])

# %%
## saves the index (0 to 5) of most likely (max) predicted class for each image
max_idxs = np.asarray(np.argmax(preds[0],axis=1))

# %%
yhat = []
for max_idx in max_idxs:
    yhat.append(data.classes[max_idx])
yhat
# Out:
# ['glass',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'metal',
#  'glass',
#  'glass',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'cardboard',
#  'plastic',
#  'trash',
#  'trash',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'plastic',
#  'metal',
#  'plastic',
#  'metal',
#  'plastic',
#  'metal',
#  'glass',
#  'metal',
#  'metal',
#  'trash',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'plastic',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'trash',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'metal',
#  'cardboard',
#  'paper',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'metal',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'cardboard',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'trash',
#  'metal',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'trash',
#  'trash',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'glass',
#  'paper',
#  'trash',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'trash',
#  'metal',
#  'metal',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'trash',
#  'metal',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'metal',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'metal',
#  'glass',
#  'glass',
#  'glass',
#  'cardboard',
#  'paper',
#  'trash',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'cardboard',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'trash',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'trash',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'metal',
#  'trash',
#  'cardboard',
#  'glass',
#  'trash',
#  'glass',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'paper',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'trash',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'metal',
#  'plastic',
#  'metal',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'trash',
#  'metal',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'glass',
#  'trash',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'trash',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'trash',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'plastic',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'plastic']

# %%
learn.data.test_ds[0][0]
# Out:
# Image (3, 384, 512)

# %%
y = []

## convert POSIX paths to string first
for label_path in data.test_ds.items:
    y.append(str(label_path))
    
## then extract waste type from file path
pattern = re.compile("([a-z]+)[0-9]+")
for i in range(len(y)):
    y[i] = pattern.search(y[i]).group(1)

# %%
## predicted values
print(yhat[0:5])
## actual values
print(y[0:5])
# Out:
# ['glass', 'metal', 'plastic', 'paper', 'paper']
# ['cardboard', 'metal', 'plastic', 'trash', 'plastic']

# %%
cm = confusion_matrix(y,yhat)
print(cm)
# Out:
# [[ 91   1   2   3   4   0]
#  [  2  85  12   3  20   4]
#  [  7  16  65   4   8   3]
#  [  7   0   5 136   1   0]
#  [  1  19   2  15  84   0]
#  [  3   1   5  10   3  13]]

# %%
df_cm = pd.DataFrame(cm,CATEGORIES,CATEGORIES)

plt.figure(figsize=(10,8))
sns.heatmap(df_cm,annot=True,fmt="d",cmap="YlGnBu")

# %%
correct = 0

for r in range(len(cm)):
    for c in range(len(cm)):
        if (r==c):
            correct += cm[r,c]

# %%
accuracy = correct/sum(sum(cm))
accuracy
# Out:
# 0.7464566929133858

# %%
learn.save('modelweights')
